# %% [markdown]
# <a href="https://colab.research.google.com/github/thebabycode/NLP/blob/main/CAT3_2147219.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
from google.colab import drive
drive.mount('/content/drive')
data = pd.read_csv('/content/drive/MyDrive/ML/HCV.csv')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data = pd.read_csv('/content/HCV.csv')

# %%
df = data

# %%
df
# Out:
#      Age Sex   ALB    ALP    ALT    AST   BIL    CHE  CHOL   CREA    GGT  \
# 0     32   m  38.5   52.5    7.7   22.1   7.5   6.93  3.23  106.0   12.1
# 1     32   m  38.5   70.3   18.0   24.7   3.9  11.17  4.80   74.0   15.6
# 2     32   m  46.9   74.7   36.2   52.6   6.1   8.84  5.20   86.0   33.2
# 3     32   m  43.2   52.0   30.6   22.6  18.9   7.33  4.74   80.0   33.8
# 4     32   m  39.2   74.1   32.6   24.8   9.6   9.15  4.32   76.0   29.9
# ..   ...  ..   ...    ...    ...    ...   ...    ...   ...    ...    ...
# 610   62   f  32.0  416.6    5.9  110.3  50.0   5.57  6.30   55.7  650.9
# 611   64   f  24.0  102.8    2.9   44.4  20.0   1.54  3.02   63.0   35.9
# 612   64   f  29.0   87.3    3.5   99.0  48.0   1.66  3.63   66.7   64.2
# 613   46   f  33.0    NaN   39.0   62.0  20.0   3.56  4.20   52.0   50.0
# 614   59   f  36.0    NaN  100.0   80.0  12.0   9.07  5.30   67.0   34.0
#
#      PROT       Category  Unnamed: 13
# 0    69.0  0=Blood Donor          NaN
# ...

# %%
df= data.head(615)
df
# Out:
#      Age Sex   ALB    ALP    ALT    AST   BIL    CHE  CHOL   CREA    GGT  \
# 0     32   m  38.5   52.5    7.7   22.1   7.5   6.93  3.23  106.0   12.1
# 1     32   m  38.5   70.3   18.0   24.7   3.9  11.17  4.80   74.0   15.6
# 2     32   m  46.9   74.7   36.2   52.6   6.1   8.84  5.20   86.0   33.2
# 3     32   m  43.2   52.0   30.6   22.6  18.9   7.33  4.74   80.0   33.8
# 4     32   m  39.2   74.1   32.6   24.8   9.6   9.15  4.32   76.0   29.9
# ..   ...  ..   ...    ...    ...    ...   ...    ...   ...    ...    ...
# 610   62   f  32.0  416.6    5.9  110.3  50.0   5.57  6.30   55.7  650.9
# 611   64   f  24.0  102.8    2.9   44.4  20.0   1.54  3.02   63.0   35.9
# 612   64   f  29.0   87.3    3.5   99.0  48.0   1.66  3.63   66.7   64.2
# 613   46   f  33.0    NaN   39.0   62.0  20.0   3.56  4.20   52.0   50.0
# 614   59   f  36.0    NaN  100.0   80.0  12.0   9.07  5.30   67.0   34.0
#
#      PROT       Category  Unnamed: 13
# 0    69.0  0=Blood Donor          NaN
# ...

# %%
uniqueCounts = df.nunique();
print("Unique count across columns:")
print(uniqueCounts);                 # printing the unique values to identify classes
# Out:
# Unique count across columns:
# Age             49
# Sex              2
# ALB            189
# ALP            414
# ALT            341
# AST            297
# BIL            188
# CHE            407
# CHOL           313
# CREA           117
# GGT            358
# PROT           198
# Category         5
# Unnamed: 13      0
# dtype: int64

# %%
df.isnull().sum()                      # total number of null values in each columns
# Out:
# Age              0
# Sex              0
# ALB              1
# ALP             18
# ALT              1
# AST              0
# BIL              0
# CHE              0
# CHOL            10
# CREA             0
# GGT              0
# PROT             1
# Category         0
# Unnamed: 13    615
# dtype: int64

# %%
df=df.drop(['Unnamed: 13'], axis=1)

# %%
df
# Out:
#      Age Sex   ALB    ALP    ALT    AST   BIL    CHE  CHOL   CREA    GGT  \
# 0     32   m  38.5   52.5    7.7   22.1   7.5   6.93  3.23  106.0   12.1
# 1     32   m  38.5   70.3   18.0   24.7   3.9  11.17  4.80   74.0   15.6
# 2     32   m  46.9   74.7   36.2   52.6   6.1   8.84  5.20   86.0   33.2
# 3     32   m  43.2   52.0   30.6   22.6  18.9   7.33  4.74   80.0   33.8
# 4     32   m  39.2   74.1   32.6   24.8   9.6   9.15  4.32   76.0   29.9
# ..   ...  ..   ...    ...    ...    ...   ...    ...   ...    ...    ...
# 610   62   f  32.0  416.6    5.9  110.3  50.0   5.57  6.30   55.7  650.9
# 611   64   f  24.0  102.8    2.9   44.4  20.0   1.54  3.02   63.0   35.9
# 612   64   f  29.0   87.3    3.5   99.0  48.0   1.66  3.63   66.7   64.2
# 613   46   f  33.0    NaN   39.0   62.0  20.0   3.56  4.20   52.0   50.0
# 614   59   f  36.0    NaN  100.0   80.0  12.0   9.07  5.30   67.0   34.0
#
#      PROT       Category
# 0    69.0  0=Blood Donor
# 1    76.5  0=Blood Donor
# ...

# %%
df.shape
# Out:
# (615, 13)

# %%
df['ALB'].fillna(value = df.ALB.mean(), inplace = True)
df['ALP'].fillna(value = df.ALP.mean(), inplace = True)
df['ALT'].fillna(value = df.ALT.mean(), inplace = True)
df['CHOL'].fillna(value = df.CHOL.mean(), inplace = True)
df['PROT'].fillna(value = df.PROT.mean(), inplace = True)

# finding the mean of each columns having the null values and filling the null values

# %%
df
# Out:
#      Age Sex   ALB        ALP    ALT    AST   BIL    CHE  CHOL   CREA    GGT  \
# 0     32   m  38.5   52.50000    7.7   22.1   7.5   6.93  3.23  106.0   12.1
# 1     32   m  38.5   70.30000   18.0   24.7   3.9  11.17  4.80   74.0   15.6
# 2     32   m  46.9   74.70000   36.2   52.6   6.1   8.84  5.20   86.0   33.2
# 3     32   m  43.2   52.00000   30.6   22.6  18.9   7.33  4.74   80.0   33.8
# 4     32   m  39.2   74.10000   32.6   24.8   9.6   9.15  4.32   76.0   29.9
# ..   ...  ..   ...        ...    ...    ...   ...    ...   ...    ...    ...
# 610   62   f  32.0  416.60000    5.9  110.3  50.0   5.57  6.30   55.7  650.9
# 611   64   f  24.0  102.80000    2.9   44.4  20.0   1.54  3.02   63.0   35.9
# 612   64   f  29.0   87.30000    3.5   99.0  48.0   1.66  3.63   66.7   64.2
# 613   46   f  33.0   68.28392   39.0   62.0  20.0   3.56  4.20   52.0   50.0
# 614   59   f  36.0   68.28392  100.0   80.0  12.0   9.07  5.30   67.0   34.0
#
#      PROT       Category
# ...

# %%
df
# Out:
#      Age Sex   ALB        ALP    ALT    AST   BIL    CHE  CHOL   CREA    GGT  \
# 0     32   m  38.5   52.50000    7.7   22.1   7.5   6.93  3.23  106.0   12.1
# 1     32   m  38.5   70.30000   18.0   24.7   3.9  11.17  4.80   74.0   15.6
# 2     32   m  46.9   74.70000   36.2   52.6   6.1   8.84  5.20   86.0   33.2
# 3     32   m  43.2   52.00000   30.6   22.6  18.9   7.33  4.74   80.0   33.8
# 4     32   m  39.2   74.10000   32.6   24.8   9.6   9.15  4.32   76.0   29.9
# ..   ...  ..   ...        ...    ...    ...   ...    ...   ...    ...    ...
# 610   62   f  32.0  416.60000    5.9  110.3  50.0   5.57  6.30   55.7  650.9
# 611   64   f  24.0  102.80000    2.9   44.4  20.0   1.54  3.02   63.0   35.9
# 612   64   f  29.0   87.30000    3.5   99.0  48.0   1.66  3.63   66.7   64.2
# 613   46   f  33.0   68.28392   39.0   62.0  20.0   3.56  4.20   52.0   50.0
# 614   59   f  36.0   68.28392  100.0   80.0  12.0   9.07  5.30   67.0   34.0
#
#      PROT       Category
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# doing minmaxscaler

# %%
df.columns
# Out:
# Index(['Age', 'Sex', 'ALB', 'ALP', 'ALT', 'AST', 'BIL', 'CHE', 'CHOL', 'CREA',
#        'GGT', 'PROT', 'Category'],
#       dtype='object')

# %%
df[['ALB', 'ALP', 'ALT', 'AST', 'BIL', 'CHE', 'CHOL', 'CREA',
       'GGT', 'PROT']] = scaler.fit_transform(df[['ALB', 'ALP', 'ALT', 'AST', 'BIL', 'CHE', 'CHOL', 'CREA',
       'GGT', 'PROT']])

# %%
df
# Out:
#      Age Sex       ALB       ALP       ALT       AST       BIL       CHE  \
# 0     32   m  0.350669  0.101653  0.020962  0.036694  0.026461  0.367578
# 1     32   m  0.350669  0.145571  0.052713  0.044990  0.012243  0.650434
# 2     32   m  0.475483  0.156427  0.108816  0.134014  0.020932  0.494997
# 3     32   m  0.420505  0.100419  0.091554  0.038290  0.071485  0.394263
# 4     32   m  0.361070  0.154947  0.097719  0.045310  0.034755  0.515677
# ..   ...  ..       ...       ...       ...       ...       ...       ...
# 610   62   f  0.254086  1.000000  0.015413  0.318124  0.194313  0.276851
# 611   64   f  0.135215  0.225759  0.006165  0.107849  0.075829  0.008005
# 612   64   f  0.209510  0.187515  0.008015  0.282068  0.186414  0.016011
# 613   46   f  0.268945  0.140597  0.117448  0.164008  0.075829  0.142762
# 614   59   f  0.313522  0.140597  0.305487  0.221442  0.044234  0.510340
#
#          CHOL      CREA       GGT      PROT       Category
# ...

# %%
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
df.Category.value_counts(normalize = True)
# normalizing the categorical values
# Out:
# 0=Blood Donor             0.866667
# 3=Cirrhosis               0.048780
# 1=Hepatitis               0.039024
# 2=Fibrosis                0.034146
# 0s=suspect Blood Donor    0.011382
# Name: Category, dtype: float64

# %%
sns.set_theme(style="whitegrid")
sns.countplot(x='Sex', data=df)

# %%
# heatmap
plt.figure(figsize=(15, 15))
plt.title("Heatmap Relation")
sns.heatmap(df.corr(), annot=True, fmt='.2f');

# %%
male = df.Sex.value_counts().loc['m']
female = df.Sex.value_counts().loc['f']
print('Males count = {}'.format(male))
print('Females count = {}'.format(female))
# Out:
# Males count = 377
# Females count = 238

# %%
df_grp = df.groupby(['Sex', 'Category'])

# %%
print('Percentage of diseased females: {:.2%}'.format((female - len(df_grp.get_group(('f', '0=Blood Donor'))))/len(df_grp.get_group(('f', '0=Blood Donor')))))
print('Percentage of diseased males: {:.2%}'.format((male - len(df_grp.get_group(('m', '0=Blood Donor'))))/len(df_grp.get_group(('m', '0=Blood Donor')))))
# Out:
# Percentage of diseased females: 10.70%
# Percentage of diseased males: 18.55%

# %% [markdown]
# Inference:
#
# So out of 377 males only 18 percentage are considered as deceased even though its a suspect blood donor and out of 238 females 10% are deceased. so it can be considered negligible because in total it affects only 1%

# %%
df.describe()
# Out:
#               Age         ALB         ALP         ALT         AST         BIL  \
# count  615.000000  615.000000  615.000000  615.000000  615.000000  615.000000
# mean    47.408130    0.397031    0.140597    0.084929    0.077174    0.041851
# std     10.055105    0.085823    0.063272    0.078449    0.105586    0.077698
# min     19.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%     39.000000    0.355126    0.102763    0.047781    0.035099    0.017773
# 50%     47.000000    0.401189    0.136689    0.068126    0.048819    0.025671
# 75%     54.000000    0.450223    0.167777    0.099106    0.071155    0.041074
# max     77.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#               CHE        CHOL        CREA         GGT        PROT
# count  615.000000  615.000000  615.000000  615.000000  615.000000
# mean     0.452077    0.477925    0.068423    0.054197    0.602746
# std      0.147142    0.136343    0.046453    0.084562    0.119430
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le_Category = LabelEncoder()
le_Sex = LabelEncoder()
dfle = df.copy()


dfle.Category = le_Category.fit_transform(dfle.Category)
dfle.Sex = le_Sex.fit_transform(dfle.Sex)

# using label encoder to rename the class labels from 0 to 4

# %%
X = dfle.drop(['Category'], axis = 'columns')
y = dfle.Category
X
# Out:
#      Age  Sex       ALB       ALP       ALT       AST       BIL       CHE  \
# 0     32    1  0.350669  0.101653  0.020962  0.036694  0.026461  0.367578
# 1     32    1  0.350669  0.145571  0.052713  0.044990  0.012243  0.650434
# 2     32    1  0.475483  0.156427  0.108816  0.134014  0.020932  0.494997
# 3     32    1  0.420505  0.100419  0.091554  0.038290  0.071485  0.394263
# 4     32    1  0.361070  0.154947  0.097719  0.045310  0.034755  0.515677
# ..   ...  ...       ...       ...       ...       ...       ...       ...
# 610   62    0  0.254086  1.000000  0.015413  0.318124  0.194313  0.276851
# 611   64    0  0.135215  0.225759  0.006165  0.107849  0.075829  0.008005
# 612   64    0  0.209510  0.187515  0.008015  0.282068  0.186414  0.016011
# 613   46    0  0.268945  0.140597  0.117448  0.164008  0.075829  0.142762
# 614   59    0  0.313522  0.140597  0.305487  0.221442  0.044234  0.510340
#
#          CHOL      CREA       GGT      PROT
# ...

# %%
sns.set_theme(style="whitegrid")
sns.countplot(x='Category', data=df)

# %%
  y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 610    4
# 611    4
# 612    4
# 613    4
# 614    4
# Name: Category, Length: 615, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.2)                   #splitting the data for logistic regression
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression(random_state=0).fit(X_train, y_train)

lr_prediction = lr.predict(X_test)
score = lr.score(X_test, y_test)
print('Logistic Regression model has {:.2%} accuracy'.format(score))
# Out:
# Logistic Regression model has 87.80% accuracy
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,

# %% [markdown]
# Inference:
# Logistic Regression model has obtained the accuracy of 87.80%

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
cm = confusion_matrix(y_test, lr_prediction)
plt.figure(figsize = (10,7))
sns.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
plt.title('Logistic Regression Confusion matrix')
# Out:
# Text(0.5, 1.0, 'Logistic Regression Confusion matrix')

# %% [markdown]
# 14 people where wrongly classified

# %%
y_pred = lr.predict(X_test)

from sklearn import metrics
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9186991869918699

# %% [markdown]
# The model is 91% accurate

# %%
sns.set_theme(style="whitegrid")
sns.countplot(x='Category', data=df)

# %%
from sklearn.metrics import classification_report
 
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96       106
#            1       0.00      0.00      0.00         1
#            2       0.50      0.20      0.29         5
#            3       1.00      0.20      0.33         5
#            4       1.00      0.83      0.91         6
#
#     accuracy                           0.92       123
#    macro avg       0.68      0.45      0.50       123
# weighted avg       0.90      0.92      0.90       123
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %% [markdown]
# From the results above, We can see that all of the methods adopted in this study can predict with the same lavel of accuracy (>>90%). However that level of accuracy refers mostly respect to blood donors. Few errors appears when it comes of disease data as seen in the confusion matrix. That means that in order to properly predict the disease we need more samples with that particular disease and less NaN within the dataset

# %% [markdown]
# ## MLP Classifier

# %%
from sklearn.neural_network import MLPClassifier

# %% [markdown]
# Relu

# %%
clf = MLPClassifier(hidden_layer_sizes=(256,128,64,32),activation="relu",random_state=1).fit(X_train, y_train)
y_pred=clf.predict(X_test)
print(clf.score(X_test, y_test))
# Out:
# 0.926829268292683
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:696: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   ConvergenceWarning,

# %%
y_pred = clf.predict(X_test)

from sklearn import metrics
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.926829268292683

# %%
from sklearn.metrics import classification_report
 
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.96       106
#            1       0.00      0.00      0.00         1
#            2       1.00      0.20      0.33         5
#            3       0.67      0.40      0.50         5
#            4       1.00      0.83      0.91         6
#
#     accuracy                           0.93       123
#    macro avg       0.72      0.49      0.54       123
# weighted avg       0.92      0.93      0.91       123
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import plot_confusion_matrix
 
color = 'black'
matrix = plot_confusion_matrix(clf, X_test, y_test, cmap=plt.cm.Blues)
matrix.ax_.set_title('Confusion Matrix', color=color)
plt.xlabel('Predicted Label', color=color)
plt.ylabel('True Label', color=color)
plt.gcf().axes[0].tick_params(colors=color)
plt.gcf().axes[1].tick_params(colors=color)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %% [markdown]
# Sigmoid activation function

# %%
clf = MLPClassifier(hidden_layer_sizes=(256,128,64,32),activation="logistic",random_state=1).fit(X_train, y_train)
y_pred=clf.predict(X_test)
print(clf.score(X_test, y_test))
# Out:
# 0.8617886178861789

# %%
y_pred = clf.predict(X_test)

from sklearn import metrics
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.8617886178861789

# %%
from sklearn.metrics import classification_report
 
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.93       106
#            1       0.00      0.00      0.00         1
#            2       0.00      0.00      0.00         5
#            3       0.00      0.00      0.00         5
#            4       0.00      0.00      0.00         6
#
#     accuracy                           0.86       123
#    macro avg       0.17      0.20      0.19       123
# weighted avg       0.74      0.86      0.80       123
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import plot_confusion_matrix
 
color = 'black'
matrix = plot_confusion_matrix(clf, X_test, y_test, cmap=plt.cm.Blues)
matrix.ax_.set_title('Confusion Matrix', color=color)
plt.xlabel('Predicted Label', color=color)
plt.ylabel('True Label', color=color)
plt.gcf().axes[0].tick_params(colors=color)
plt.gcf().axes[1].tick_params(colors=color)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %% [markdown]
# **Tanh** or **Tan inverse**

# %%
clf = MLPClassifier(hidden_layer_sizes=(256,128,64,32),activation="tanh",random_state=1).fit(X_train, y_train)
y_pred=clf.predict(X_test)
print(clf.score(X_test, y_test))
# Out:
# 0.926829268292683

# %%
y_pred = clf.predict(X_test)

from sklearn import metrics
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.926829268292683

# %%
from sklearn.metrics import classification_report
 
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96       106
#            1       0.00      0.00      0.00         1
#            2       0.75      0.60      0.67         5
#            3       0.67      0.80      0.73         5
#            4       0.71      0.83      0.77         6
#
#     accuracy                           0.93       123
#    macro avg       0.62      0.64      0.63       123
# weighted avg       0.92      0.93      0.92       123
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %% [markdown]
# Weights

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import plot_confusion_matrix
 
color = 'black'
matrix = plot_confusion_matrix(clf, X_test, y_test, cmap=plt.cm.Blues)
matrix.ax_.set_title('Confusion Matrix', color=color)
plt.xlabel('Predicted Label', color=color)
plt.ylabel('True Label', color=color)
plt.gcf().axes[0].tick_params(colors=color)
plt.gcf().axes[1].tick_params(colors=color)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %%
print (clf.coefs_)
# Out:
# [array([[-0.02964949,  0.03387607, -0.19609111, ...,  0.1949325 ,
#          0.00914934,  0.14109001],
#        [ 0.04093374, -0.01640917, -0.09050944, ..., -0.02473434,
#         -0.04064347, -0.00066473],
#        [-0.094978  , -0.17326604,  0.00137797, ..., -0.07529892,
#          0.06457767,  0.060328  ],
#        ...,
#        [-0.08492574, -0.08918492,  0.01941353, ...,  0.00226135,
#          0.01570591,  0.0739275 ],
#        [ 0.1150355 ,  0.00250906, -0.00292418, ..., -0.04786246,
#         -0.27439997, -0.0144335 ],
#        [-0.07640225,  0.03584766, -0.10748522, ...,  0.12696194,
#         -0.20301939, -0.05161939]]), array([[ 0.12076849, -0.05216414,  0.07297109, ...,  0.04289903,
#          0.05239843,  0.08645102],
#        [-0.08372967,  0.0624207 ,  0.05175556, ..., -0.03640808,
#         -0.0731891 ,  0.07812799],
#        [ 0.00212539,  0.09721733, -0.09123876, ..., -0.04884608,
#         -0.10534357, -0.01336323],
#        ...,
# ...
